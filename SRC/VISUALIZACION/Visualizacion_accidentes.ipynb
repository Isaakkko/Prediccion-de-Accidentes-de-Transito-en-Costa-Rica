# %% [markdown]
# ### Las siguientes 3 lineas de codigo son para poder cargar la clase

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP'

# %%
os.chdir("C:\Proyecto_accidentes")
os.listdir()
# Out:
# ['visualizador_accidentes.py', '__pycache__']

# %%
os.listdir()
# Out:
# ['visualizador_accidentes.py', '__pycache__']

# %% [markdown]
# ### Aqui importamos lo que es la clase visualizador

# %%
from importlib import reload
import visualizador_accidentes

reload(visualizador_accidentes)

from visualizador_accidentes import Visualizador

# %% [markdown]
# ### Se lee el dataset

# %%
import pandas as pd
df = pd.read_csv("C:\Base_de_accidentes_con_victimas_clean.csv")

# %% [markdown]
# ### Se crea la instancia del visualizador

# %%
viz = Visualizador(df)
# Out:
# Datos cargados: 104898 registros

# %% [markdown]
# ### Primer grafico de barras sobre cual es la provincia con mas accidentes del 2018-2024

# %%
viz.grafico_provincia_mas_accidentes_por_año()

# %% [markdown]
# ### Histograma sobre las horas en las que mas ocurren accidentes

# %%
viz.grafico_accidentes_por_hora()

# %% [markdown]
# ### Grafico de los 10 cantones con mas accidentes en el pais

# %%
viz.grafico_top_10_cantones()

# %% [markdown]
# ### Grafico de la cantidad total de accidentes por provincia

# %%
viz.grafico_accidentes_por_provincia()
